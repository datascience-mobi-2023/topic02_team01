# %%
import pandas as pd 
import numpy as np
import statistics as st
#df = pd.read_csv(r'Stiffler_Amp_Trial1&2CSV.CSV')

# %%
df = pd.read_excel(r"C:\Users\sveam\Documents\MOBI 23\Bioinfo\Stiffler_Amp_Trial1&2.xlsx")
# Out:
# c:\Users\sveam\anaconda3.2\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
names = df.iloc[:,0]
names
trial1 = df.iloc[1:,1:7]
trial1

trial2= df.iloc[1:,9:14]
trial2
amp = df.iloc[1,1:7]
amp

trial1.columns = amp
trial2.columns = [0,39,156,625,2500]
# Out:
# -2.53530331726744

# %%
averagelist= []
for i in range (1,4997):
    a = trial1.iloc[i,-1]
    b = trial2.iloc[i,-1]#
    average = (a+b)/2
    averagelist.append(average)
averagelist
# Out:
# [-0.009783564891610766,
#  -0.41825992496382247,
#  -0.181606609443043,
#  -0.2790241682621575,
#  -0.818487095332004,
#  -0.060241672514045996,
#  -0.359191242313471,
#  0.014469576534598893,
#  -0.480346575601756,
#  -0.22478129217770348,
#  -0.043093162745745914,
#  -1.010848138340375,
#  -0.13556833375591837,
#  -0.00252625820487169,
#  0.03616609695620455,
#  -0.0671875460210681,
#  -0.02687404696750926,
#  -1.3475859605154685,
#  -0.8850251495507191,
#  -1.64259509301233,
#  -0.364138404441956,
#  -0.028402505048950553,
#  0.143257860666155,
#  -0.19980403105601402,
#  -0.9692678611258865,
#  0.04578461828514165,
#  -0.07352383617042385,
#  0.1355904993222355,
#  -0.2118689221436385,
#  -0.028365739929591904,
#  0.0206404860011586,
#  -0.02821362152090045,
#  0.054153992793284825,
#  -0.160130435919047,
#  -0.09119994832231465,
#  0.045912990573576354,
#  -0.1091385952314715,
#  0.0017446675254475102,
#  0.010913107828748502,
#  -0.15823261145329598,
#  -0.07578524008140206,
# ...

# %%
trial2.iloc[0,-1]
# Out:
# 2500.0

# %%
av_list_median= []
for i in range (0,4997):
    a = trial1.iloc[i,0]
    b = trial2.iloc[i,0]
    average = (a+b)/2
    av_list_median.append(average)
av_list_median
# Out:
# [0.0,
#  0.014913340061006796,
#  0.02270234429445975,
#  0.04230135600308635,
#  0.01138711860088009,
#  0.02059895155317525,
#  0.011460419627292778,
#  0.008072383618888731,
#  0.0398876167770015,
#  -0.007130207618593975,
#  0.02537379684440355,
#  0.007222492174745231,
#  -0.133874583138654,
#  0.0060299934637166805,
#  0.016832360077803803,
#  -0.00815444718644994,
#  0.02039926969945525,
#  0.02671071745457655,
#  -0.00630729815701047,
#  -0.0215737504886676,
#  -0.10386603827809354,
#  -0.03521136541229945,
#  0.004797193170703554,
#  -0.011457153718637699,
#  -0.012487660871508,
#  -0.02390933967053065,
#  0.02947797230561705,
#  -0.028071817531551455,
#  -0.0662888909080295,
#  -0.005307255893973595,
#  -0.0928226095085556,
#  -0.05155988658146565,
#  0.13801046263375188,
#  -0.01370615365564493,
#  -0.039348433260890756,
#  -0.0769339266921408,
#  -0.027791512865109648,
#  0.013600483312539989,
#  -0.0947272003738797,
#  -0.06008871413625935,
#  0.051185296124983806,
# ...

# %% [markdown]
# Ist der DMS_median = median[Amp=0]?
# --> Nein

# %%
x = st.median(av_list_median)
av_list_median
print(x)
# Out:
# -0.016120822430113875

# %%
cutoff = -1.159498916
threshold = x+cutoff
bin = {}

# %%
for i in averagelist:
    if i >= threshold:
        bin[i] = 1
    else:
        bin[i]= 0

bin
# Out:
# {2500.0: 1,
#  -0.009783564891610766: 1,
#  -0.41825992496382247: 1,
#  -0.181606609443043: 1,
#  -0.2790241682621575: 1,
#  -0.818487095332004: 1,
#  -0.060241672514045996: 1,
#  -0.359191242313471: 1,
#  0.014469576534598893: 1,
#  -0.480346575601756: 1,
#  -0.22478129217770348: 1,
#  -0.043093162745745914: 1,
#  -1.010848138340375: 1,
#  -0.13556833375591837: 1,
#  -0.00252625820487169: 1,
#  0.03616609695620455: 1,
#  -0.0671875460210681: 1,
#  -0.02687404696750926: 1,
#  -1.3475859605154685: 0,
#  -0.8850251495507191: 1,
#  -1.64259509301233: 0,
#  -0.364138404441956: 1,
#  -0.028402505048950553: 1,
#  0.143257860666155: 1,
#  -0.19980403105601402: 1,
#  -0.9692678611258865: 1,
#  0.04578461828514165: 1,
#  -0.07352383617042385: 1,
#  0.1355904993222355: 1,
#  -0.2118689221436385: 1,
#  -0.028365739929591904: 1,
#  0.0206404860011586: 1,
#  -0.02821362152090045: 1,
#  0.054153992793284825: 1,
#  -0.160130435919047: 1,
#  -0.09119994832231465: 1,
#  0.045912990573576354: 1,
# ...

# %%
df
# Out:
#        Trial 1                        Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN  Ampicillin concentration (ug/mL)         NaN         NaN
# 1     Mutation                                 0   10.000000   39.000000
# 2         H26A                          0.002119   -0.012885   -0.015205
# 3         H26C                         -0.037095    0.002591   -0.042346
# 4         H26D                          0.033849    0.002764   -0.007401
# ...        ...                               ...         ...         ...
# 4994     W290R                          0.006037   -0.080176   -0.039498
# 4995     W290S                          0.003713   -0.061769   -0.024788
# 4996     W290T                         -0.006306   -0.074702   -0.012398
# 4997     W290V                          0.029899   -0.038513   -0.039365
# 4998     W290Y                         -0.019271    0.024544   -0.016550
#
#       Unnamed: 4  Unnamed: 5   Unnamed: 6  Unnamed: 7   Trial 2  \
# ...
